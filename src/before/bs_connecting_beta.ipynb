# %%
import requests
import pandas as pd
import re

# %%
def check_date(date):
    try:
        date_pattern = r'\d{4}-\d{2}-\d{2}'
        if re.match(date_pattern, date):
            if int(date[:4]) < 2019:
                return f'after={date}T12%3A02%3A36.874Z'
            else:
                return f'before={date}T12%3A02%3A36.874Z'
    except:
        return ''

# %%
query_date = input('enter YYYY-MM-DD for a specific date. improper date formats will show most recent songs') ## This will turn into a button on streamlit

bs_url = 'https://api.beatsaver.com/maps/latest?' #yep, hardcoded url right now
search_date_formatted = check_date(query_date)
url_end = '&pageSize=50'

# %%
# gets fresh data from beat saver
response = requests.get(f'{bs_url}{search_date_formatted}{url_end}').json()

# %% [markdown]
# # looking at the guts

# %%
response['docs']
# Out:
# [{'id': '31b57',
#   'name': 'Tin Soldier - Small Faces (V3)',
#   'description': "A great song from the Small Faces, Tin Soldier was released  on 2 December 1967, written by Steve Marriott (credited to Marriott/Lane). The song peaked at number nine in the UK singles chart\r\n\r\nIts a fairly easy expt level with nothing too challenging, so I've thrown in a few arcs for fun. I did think of setting it as hard but some of the drum breaks are a little too quick.\r\n\r\n",
#   'uploader': {'id': 4303354,
#    'name': 'Dtribe',
#    'avatar': 'https://www.gravatar.com/avatar/8fbfd763644ae2443c4793d49768ad53?d=retro',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4303354/playlist'},
#   'metadata': {'bpm': 112.29,
#    'duration': 206,
#    'songName': 'Tin Soldier',
#    'songSubName': '',
#    'songAuthorName': 'Small Faces',
#    'levelAuthorName': 'DTribe'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 2,
#    'downvotes': 0,
#    'score': 0.6771},
#   'uploaded': '2023-04-20T19:11:00.762442Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': 'ac77a4b85a4b4b4b5cda81dcbaeee53c52f730ca',
#     'state': 'Published',
#     'createdAt': '2023-04-20T19:10:49.913981Z',
#     'sageScore': 3,
#     'diffs': [{'njs': 16.0,
#       'offset': 0.0,
#       'notes': 647,
#       'bombs': 0,
#       'obstacles': 8,
#       'nps': 3.441,
#       'length': 351.844,
#       'characteristic': 'Standard',
#       'difficulty': 'Expert',
#       'events': 965,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 188.001,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 587995}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/ac77a4b85a4b4b4b5cda81dcbaeee53c52f730ca.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/ac77a4b85a4b4b4b5cda81dcbaeee53c52f730ca.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/ac77a4b85a4b4b4b5cda81dcbaeee53c52f730ca.mp3'}],
#   'createdAt': '2023-04-20T19:10:49.913981Z',
#   'updatedAt': '2023-04-20T19:11:00.762442Z',
#   'lastPublishedAt': '2023-04-20T19:11:00.762442Z',
#   'tags': ['balanced', 'rock'],
#   'bookmarked': False},
#  {'id': '31b56',
#   'name': 'Break Shit [cinema]',
#   'description': 'why are you reading this?',
#   'uploader': {'id': 4349118,
#    'name': 'some1krille',
#    'avatar': 'https://cdn.beatsaver.com/avatar/78a938cc5be866e454b157e8374d5dadff61fd45.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4349118/playlist'},
#   'metadata': {'bpm': 188.0,
#    'duration': 107,
#    'songName': 'Break Shit',
#    'songSubName': '',
#    'songAuthorName': 'Jasiah',
#    'levelAuthorName': 'some1krille'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 4,
#    'downvotes': 2,
#    'score': 0.5972},
#   'uploaded': '2023-04-20T18:49:04.422307Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '23e8c747417992eb4be68fa4597e2cd6bdd4eb22',
#     'state': 'Published',
#     'createdAt': '2023-04-20T18:48:33.476587Z',
#     'diffs': [{'njs': 19.0,
#       'offset': 0.0,
#       'notes': 719,
#       'bombs': 29,
#       'obstacles': 0,
#       'nps': 7.802,
#       'length': 288.75,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 0,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': True,
#       'seconds': 92.154,
#       'paritySummary': {'errors': 2, 'warns': 2, 'resets': 4},
#       'maxScore': 654235,
#       'label': 'fuck you bitch'}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/23e8c747417992eb4be68fa4597e2cd6bdd4eb22.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/23e8c747417992eb4be68fa4597e2cd6bdd4eb22.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/23e8c747417992eb4be68fa4597e2cd6bdd4eb22.mp3'}],
#   'createdAt': '2023-04-20T18:48:33.476587Z',
#   'updatedAt': '2023-04-20T18:49:04.422307Z',
#   'lastPublishedAt': '2023-04-20T18:49:04.422307Z',
#   'bookmarked': False},
#  {'id': '31b54',
#   'name': '[chllange speed] Sister\'s Noise - (takehirotei "20001th noise" remix)',
#   'description': 'Misaka <3\nWaring: Very fast Jumps at the end! \n\nExpert Plus Video: https://www.youtube.com/watch?v=dL-1UR4LsBU\n\nThanks @DiscoBaIIerz for your awesome tips and modding ^^\n\nEnjoy  :-}\n',
#   'uploader': {'id': 82944,
#    'name': 'Chrisvenator',
#    'hash': '5cff0b7698cc5a672c8546bc',
#    'avatar': 'https://cdn.beatsaver.com/avatar/497122a51e7ab3dccd8c602bb269003769812d1d.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/82944/playlist'},
#   'metadata': {'bpm': 388.0,
#    'duration': 148,
#    'songName': "Sister's Noise",
#    'songSubName': '(takehirotei "20001th noise" remix)',
#    'songAuthorName': 'fripside',
#    'levelAuthorName': 'Chrisvenator'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 8,
#    'downvotes': 1,
#    'score': 0.7562},
#   'uploaded': '2023-04-20T18:19:36.093804Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '6233606dc1ebf0107221678c60fe6baab1877925',
#     'state': 'Published',
#     'createdAt': '2023-04-20T18:15:53.681013Z',
#     'sageScore': 5,
#     'diffs': [{'njs': 22.5,
#       'offset': -0.968,
#       'notes': 1443,
#       'bombs': 165,
#       'obstacles': 208,
#       'nps': 10.415,
#       'length': 896.0,
#       'characteristic': 'Standard',
#       'difficulty': 'Expert',
#       'events': 6696,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 138.557,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 6},
#       'maxScore': 1320315,
#       'label': 'Imouto (EX+)'},
#      {'njs': 22.5,
#       'offset': -0.968,
#       'notes': 1448,
#       'bombs': 165,
#       'obstacles': 208,
#       'nps': 10.451,
#       'length': 896.0,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 6696,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 138.557,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 6},
#       'maxScore': 1324915,
#       'label': 'Onee-sama (EX++)'},
#      {'njs': 22.5,
#       'offset': -0.968,
#       'notes': 1691,
#       'bombs': 165,
#       'obstacles': 208,
#       'nps': 12.204,
#       'length': 896.0,
#       'characteristic': 'Lawless',
#       'difficulty': 'ExpertPlus',
#       'events': 6696,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 138.557,
#       'paritySummary': {'errors': 5, 'warns': 7, 'resets': 6},
#       'maxScore': 1548475}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/6233606dc1ebf0107221678c60fe6baab1877925.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/6233606dc1ebf0107221678c60fe6baab1877925.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/6233606dc1ebf0107221678c60fe6baab1877925.mp3'}],
#   'createdAt': '2023-04-20T18:15:53.681013Z',
#   'updatedAt': '2023-06-05T22:10:09.819012Z',
#   'lastPublishedAt': '2023-04-20T18:19:36.093804Z',
#   'tags': ['speed', 'anime', 'speedcore'],
#   'bookmarked': False},
#  {'id': '31b53',
#   'name': 'Sirius - BLAST-NOVA',
#   'description': 'QRESTFALL V2 ??????????!!!!! 😲😲😲😱😱😱😱😱\n\ntime to wait 89754326 yyears so i can bother to make lowers\n\ncool collab with @unluckyL he actually mapped something good (😱)',
#   'uploader': {'id': 4284468,
#    'name': 'Aquaflee',
#    'hash': '5f93369db27da400077245b3',
#    'avatar': 'https://cdn.beatsaver.com/avatar/b9c78a3aa5a1f08b2d1231fcdbf3476a14e1ff7d.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4284468/playlist'},
#   'metadata': {'bpm': 260.0,
#    'duration': 226,
#    'songName': 'BLAST-NOVA',
#    'songSubName': '',
#    'songAuthorName': 'Sirius',
#    'levelAuthorName': 'unluckyL & Aquaflee'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 44,
#    'downvotes': 3,
#    'score': 0.8782,
#    'reviews': 1},
#   'uploaded': '2023-04-20T18:14:39.388943Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '0e408f688b75775caf31dcd496aec02df8ac4c21',
#     'state': 'Published',
#     'createdAt': '2023-04-20T18:14:25.553821Z',
#     'sageScore': 6,
#     'diffs': [{'njs': 21.0,
#       'offset': -0.1,
#       'notes': 1957,
#       'bombs': 131,
#       'obstacles': 208,
#       'nps': 9.422,
#       'length': 900.083,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 8494,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 207.712,
#       'paritySummary': {'errors': 2, 'warns': 7, 'resets': 23},
#       'maxScore': 1793195,
#       'label': '💫'}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/0e408f688b75775caf31dcd496aec02df8ac4c21.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/0e408f688b75775caf31dcd496aec02df8ac4c21.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/0e408f688b75775caf31dcd496aec02df8ac4c21.mp3'}],
#   'curator': {'id': 4288866,
#    'name': 'GeneralDum',
#    'hash': '5f47d17f530c8e00062903c9',
#    'avatar': 'https://cdn.beatsaver.com/avatar/c7d25218cee2429fb3aae7180aa2f56744826dc6.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': True,
#    'curatorTab': True,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4288866/playlist'},
#   'curatedAt': '2023-04-24T15:06:49.220618Z',
#   'createdAt': '2023-04-20T18:14:25.553821Z',
#   'updatedAt': '2023-04-24T15:06:49.220618Z',
#   'lastPublishedAt': '2023-04-20T18:14:39.388943Z',
#   'bookmarked': False},
#  {'id': '31b52',
#   'name': 'IVE - Blue Blood',
#   'description': "What's your blood type?\nI'm blue\n\nExpert+ Gameplay\nhttps://youtu.be/cSTgp2Hb09w\n\nJoin Beat Saber KPOP Discord!\nhttps://discord.gg/c9uHGYP\n\nLike most/all of my kpop maps? Use this playlist! (always up to date)\nhttps://beatsaver.com/playlists/315\n\nThanks to @tocxx for playtesting and feedback on Expert+\n\nFeedback is always appreciated\nDiscord: eurnkung#6176",
#   'uploader': {'id': 4285115,
#    'name': 'eurnkung',
#    'hash': '609a7955686b9f0006a47313',
#    'avatar': 'https://cdn.beatsaver.com/avatar/d91ebeaac5291083052d6a4592ae428374039f0a.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4285115/playlist'},
#   'metadata': {'bpm': 99.0,
#    'duration': 170,
#    'songName': 'Blue Blood',
#    'songSubName': '',
#    'songAuthorName': 'IVE',
#    'levelAuthorName': 'eurnkung'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 82,
#    'downvotes': 7,
#    'score': 0.8835},
#   'uploaded': '2023-04-20T17:49:33.576193Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '9567cb14d9d9f8fdfa7499a6a6aedf1ecddc33d7',
#     'state': 'Published',
#     'createdAt': '2023-04-20T17:44:53.580542Z',
#     'sageScore': 3,
#     'diffs': [{'njs': 13.0,
#       'offset': -0.54,
#       'notes': 395,
#       'bombs': 0,
#       'obstacles': 52,
#       'nps': 2.455,
#       'length': 265.5,
#       'characteristic': 'Standard',
#       'difficulty': 'Hard',
#       'events': 2821,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 160.909,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 356155},
#      {'njs': 15.0,
#       'offset': 0.21,
#       'notes': 553,
#       'bombs': 0,
#       'obstacles': 72,
#       'nps': 3.437,
#       'length': 265.5,
#       'characteristic': 'Standard',
#       'difficulty': 'Expert',
#       'events': 2821,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 160.909,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 501515},
#      {'njs': 17.0,
#       'offset': 0.0,
#       'notes': 702,
#       'bombs': 4,
#       'obstacles': 103,
#       'nps': 4.363,
#       'length': 265.5,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 2821,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 160.909,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 638595}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/9567cb14d9d9f8fdfa7499a6a6aedf1ecddc33d7.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/9567cb14d9d9f8fdfa7499a6a6aedf1ecddc33d7.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/9567cb14d9d9f8fdfa7499a6a6aedf1ecddc33d7.mp3'}],
#   'createdAt': '2023-04-20T17:44:53.580542Z',
#   'updatedAt': '2023-04-20T17:49:33.576193Z',
#   'lastPublishedAt': '2023-04-20T17:49:33.576193Z',
#   'tags': ['balanced', 'dance-style', 'k-pop'],
#   'bookmarked': False},
#  {'id': '31b51',
#   'name': 'Kaneko chiharu - ILLness LiLin',
#   'description': 'Thanks for Requested! \r\n\r\nThis map is made for Song Requested',
#   'uploader': {'id': 4285211,
#    'name': 'komeijisan051',
#    'hash': '5e74cb357abb000006893ebd',
#    'avatar': 'https://cdn.beatsaver.com/avatar/7b73b7df2414a63027d9f6b0a2160c5a32142dee.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4285211/playlist'},
#   'metadata': {'bpm': 280.0,
#    'duration': 122,
#    'songName': 'ILLness LiLin',
#    'songSubName': '',
#    'songAuthorName': 'Kaneko chiharu',
#    'levelAuthorName': 'Komeijisan051'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 35,
#    'downvotes': 1,
#    'score': 0.8985},
#   'uploaded': '2023-04-20T17:23:29.812361Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '88fa018d0d6c71864d3a951717766c9496336686',
#     'state': 'Published',
#     'createdAt': '2023-04-20T17:23:11.173721Z',
#     'sageScore': 3,
#     'diffs': [{'njs': 17.0,
#       'offset': -0.8,
#       'notes': 734,
#       'bombs': 89,
#       'obstacles': 279,
#       'nps': 6.297,
#       'length': 544.0,
#       'characteristic': 'Standard',
#       'difficulty': 'Hard',
#       'events': 6650,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 116.571,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 5},
#       'maxScore': 668035},
#      {'njs': 20.0,
#       'offset': -1.4,
#       'notes': 1174,
#       'bombs': 93,
#       'obstacles': 134,
#       'nps': 10.071,
#       'length': 544.0,
#       'characteristic': 'Standard',
#       'difficulty': 'Expert',
#       'events': 6650,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 116.571,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 7},
#       'maxScore': 1072835},
#      {'njs': 22.0,
#       'offset': 0.25,
#       'notes': 1635,
#       'bombs': 0,
#       'obstacles': 76,
#       'nps': 14.026,
#       'length': 544.0,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 6729,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 116.571,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 1496955}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/88fa018d0d6c71864d3a951717766c9496336686.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/88fa018d0d6c71864d3a951717766c9496336686.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/88fa018d0d6c71864d3a951717766c9496336686.mp3'}],
#   'createdAt': '2023-04-20T17:23:11.173721Z',
#   'updatedAt': '2023-04-20T17:23:29.812361Z',
#   'lastPublishedAt': '2023-04-20T17:23:29.812361Z',
#   'bookmarked': False},
#  {'id': '31b4f',
#   'name': 'cobu - 御仕置き-愛のテーマ-',
#   'description': '30作目ですよー\n\n※注意！\n特殊譜面です。苦手な方はご注意ください。\n\n・BGM\n御仕置き-愛のテーマ-～cobu～\n「幻想少女大戦 妖」より',
#   'uploader': {'id': 4342868,
#    'name': 'MAC2625',
#    'avatar': 'https://cdn.beatsaver.com/avatar/4342868.jpg',
#    'type': 'SIMPLE',
#    'admin': False,
#    'curator': False,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4342868/playlist'},
#   'metadata': {'bpm': 136.0,
#    'duration': 87,
#    'songName': '御仕置き-愛のテーマ-',
#    'songSubName': '懐かしき東方の血',
#    'songAuthorName': 'cobu',
#    'levelAuthorName': 'MAC'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 40,
#    'downvotes': 3,
#    'score': 0.8699},
#   'uploaded': '2023-04-20T17:18:53.265480Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': 'dd5d27a6455253ca84e3cd9ca150a3c630ecae53',
#     'state': 'Published',
#     'createdAt': '2023-04-20T16:58:20.460692Z',
#     'sageScore': 2,
#     'diffs': [{'njs': 12.0,
#       'offset': 0.0,
#       'notes': 1080,
#       'bombs': 32,
#       'obstacles': 23,
#       'nps': 13.625,
#       'length': 179.667,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 124,
#       'chroma': True,
#       'me': False,
#       'ne': True,
#       'cinema': False,
#       'seconds': 79.265,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 986355,
#       'label': 'oshioki'}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/dd5d27a6455253ca84e3cd9ca150a3c630ecae53.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/dd5d27a6455253ca84e3cd9ca150a3c630ecae53.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/dd5d27a6455253ca84e3cd9ca150a3c630ecae53.mp3'}],
#   'createdAt': '2023-04-20T16:58:20.460692Z',
#   'updatedAt': '2023-04-23T05:44:30.985511Z',
#   'lastPublishedAt': '2023-04-20T17:18:53.265480Z',
#   'tags': ['video-game-soundtrack'],
#   'bookmarked': False},
#  {'id': '31b11',
#   'name': 'NF - HAPPY [Wallmap]',
#   'description': '“Headed down a dangerous road”\n\n.\n\nMy first wallmap. I had a lot of fun with this. Enjoy!\n\nThank you for playtesting: @Hexagonial, @Symphonic, @Luposity, @Danielduel\nThis map wouldn’t be where it’s at without them.\n\nPlease disable any visual wall settings you may have. Transparent walls are fine.\n\nhttps://youtu.be/06-Rn-zU3aY a video does not do this map justice.\n\nIdk why it says 0 walls there’s about 30k.\n\nRequirements: Noddle Extensions and Chroma\n\noops I forgor to add counters+ settings ¯\\_(ツ)_/¯',
#   'uploader': {'id': 4338492,
#    'name': 'ben208',
#    'avatar': 'https://cdn.beatsaver.com/avatar/6ddababc971e42a3fce7b2d4445ade6b4c976892.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4338492/playlist'},
#   'metadata': {'bpm': 106.0,
#    'duration': 243,
#    'songName': 'HAPPY',
#    'songSubName': '',
#    'songAuthorName': 'NF',
#    'levelAuthorName': 'ben208'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 283,
#    'downvotes': 3,
#    'score': 0.9682,
#    'reviews': 1},
#   'uploaded': '2023-04-20T17:00:04.520862Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': 'ae8603bcb1f6fb0e2dc106d1a565cc3a621f0180',
#     'state': 'Published',
#     'createdAt': '2023-04-19T22:09:31.399252Z',
#     'sageScore': 2,
#     'diffs': [{'njs': 15.0,
#       'offset': -0.75,
#       'notes': 665,
#       'bombs': 0,
#       'obstacles': 0,
#       'nps': 2.846,
#       'length': 412.797,
#       'characteristic': 'Standard',
#       'difficulty': 'Expert',
#       'events': 0,
#       'chroma': True,
#       'me': False,
#       'ne': True,
#       'cinema': False,
#       'seconds': 233.659,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 604555},
#      {'njs': 15.0,
#       'offset': -0.75,
#       'notes': 0,
#       'bombs': 0,
#       'obstacles': 0,
#       'nps': 0.0,
#       'length': 0.0,
#       'characteristic': 'Lightshow',
#       'difficulty': 'Expert',
#       'events': 0,
#       'chroma': True,
#       'me': False,
#       'ne': True,
#       'cinema': False,
#       'seconds': 0.0,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 0,
#       'label': 'Just Walls'},
#      {'njs': 15.0,
#       'offset': -0.75,
#       'notes': 665,
#       'bombs': 0,
#       'obstacles': 0,
#       'nps': 2.846,
#       'length': 412.797,
#       'characteristic': 'Lawless',
#       'difficulty': 'Expert',
#       'events': 0,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 233.659,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 604555,
#       'label': 'Just Mapping'}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/ae8603bcb1f6fb0e2dc106d1a565cc3a621f0180.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/ae8603bcb1f6fb0e2dc106d1a565cc3a621f0180.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/ae8603bcb1f6fb0e2dc106d1a565cc3a621f0180.mp3'}],
#   'curator': {'id': 11586,
#    'name': 'Kansas',
#    'hash': '5f813ecf6fd2400006d03fdd',
#    'avatar': 'https://cdn.beatsaver.com/avatar/01f95562c3153874aaa65422462281189fe4a59e.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'curatorTab': True,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/11586/playlist'},
#   'curatedAt': '2023-04-21T05:40:18.796055Z',
#   'createdAt': '2023-04-19T21:25:40.821110Z',
#   'updatedAt': '2023-04-26T16:26:10.786296Z',
#   'lastPublishedAt': '2023-04-20T17:00:04.520862Z',
#   'tags': ['balanced', 'accuracy', 'pop', 'hip-hop-rap'],
#   'bookmarked': False},
#  {'id': '31b4e',
#   'name': '[DOOM Mixtape] Rip & Tear',
#   'description': "Part of the DOOM Mixtape playlist: https://beatsaver.com/playlists/103822\n\nRip and tear... until it is done!\n\nMap info:\n-Difficulties-\nExpert+\nExpert\nHard\n-Lighting-\nChroma (Panic Environment)\n\nFeedback greatly appreciated through Beat Saver reviews or DM me on discord: JohnieCanine#4833\n\nMap changelog:\nv1.1 (5/2/2023): Adjusted right color to a bit more yellow so it's not too similar to red on the left color",
#   'uploader': {'id': 4321072,
#    'name': 'JohnieCanine',
#    'avatar': 'https://cdn.beatsaver.com/avatar/7bed4a28cfbe80ae12b90216c89db0dd027e482c.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4321072/playlist'},
#   'metadata': {'bpm': 216.0,
#    'duration': 227,
#    'songName': 'Rip & Tear',
#    'songSubName': '',
#    'songAuthorName': 'Mick Gordon',
#    'levelAuthorName': 'JohnieCanine'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 230,
#    'downvotes': 26,
#    'score': 0.8799,
#    'reviews': 2},
#   'uploaded': '2023-04-20T16:55:18.840104Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': 'b95159298ded22a95715725f2eb42e0dc5fa3fc8',
#     'state': 'Published',
#     'createdAt': '2023-05-02T14:01:00.737856Z',
#     'sageScore': 2,
#     'diffs': [{'njs': 17.0,
#       'offset': 0.012,
#       'notes': 868,
#       'bombs': 200,
#       'obstacles': 262,
#       'nps': 4.019,
#       'length': 777.5,
#       'characteristic': 'Standard',
#       'difficulty': 'Hard',
#       'events': 10345,
#       'chroma': True,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 215.972,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 791315,
#       'label': 'Hurt Me Plenty'},
#      {'njs': 18.0,
#       'offset': -0.1,
#       'notes': 1120,
#       'bombs': 172,
#       'obstacles': 210,
#       'nps': 5.179,
#       'length': 778.5,
#       'characteristic': 'Standard',
#       'difficulty': 'Expert',
#       'events': 10345,
#       'chroma': True,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 216.25,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 1023155,
#       'label': 'Ultra-Violence'},
#      {'njs': 20.0,
#       'offset': -0.29,
#       'notes': 1336,
#       'bombs': 69,
#       'obstacles': 107,
#       'nps': 6.182,
#       'length': 778.0,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 10345,
#       'chroma': True,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 216.111,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 1221875,
#       'label': 'Nightmare'}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/b95159298ded22a95715725f2eb42e0dc5fa3fc8.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/b95159298ded22a95715725f2eb42e0dc5fa3fc8.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/b95159298ded22a95715725f2eb42e0dc5fa3fc8.mp3'}],
#   'curator': {'id': 4292041,
#    'name': 'symphonic',
#    'avatar': 'https://cdn.beatsaver.com/avatar/2dc906ee5b78c2cb723f0eae964c2c203babf3f4.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': True,
#    'curatorTab': True,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4292041/playlist'},
#   'curatedAt': '2023-04-21T04:26:09.276194Z',
#   'createdAt': '2023-04-20T16:55:07.934355Z',
#   'updatedAt': '2023-05-21T16:43:15.993937Z',
#   'lastPublishedAt': '2023-05-02T14:01:11.889152Z',
#   'tags': ['balanced', 'speed', 'metal', 'video-game-soundtrack'],
#   'bookmarked': False},
#  {'id': '31b4d',
#   'name': 'Broken Minds & Ender - World Control (Hardcore /  Uptempo)',
#   'description': 'ILLUMINATI, YOU’VE COME TO TAKE CONTROL.\r\nYOU CAN TAKE MY HEART BEAT,\r\nBUT YOU CAN’T BREAK MY SOUL\r\nWE ALL SHALL BE FREE!',
#   'uploader': {'id': 139205,
#    'name': 'SpencerWWW2',
#    'avatar': 'https://cdn.beatsaver.com/avatar/e560aa495b31f85db26cba3f72f27d960a1a3036.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/139205/playlist'},
#   'metadata': {'bpm': 100.0,
#    'duration': 164,
#    'songName': 'Broken Minds & Ender - World Control',
#    'songSubName': 'Hardcore / Uptempo',
#    'songAuthorName': 'Broken Minds, Ender',
#    'levelAuthorName': 'Spencer'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 2,
#    'downvotes': 0,
#    'score': 0.6771},
#   'uploaded': '2023-04-20T16:28:26.036320Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': 'b117e66ce8a50901bb1cf97db6e1833ac9afa159',
#     'state': 'Published',
#     'createdAt': '2023-04-20T16:27:56.461906Z',
#     'sageScore': 2,
#     'diffs': [{'njs': 17.0,
#       'offset': 0.5,
#       'notes': 1180,
#       'bombs': 46,
#       'obstacles': 3,
#       'nps': 7.449,
#       'length': 264.0,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 1260,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 158.4,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 1078355}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/b117e66ce8a50901bb1cf97db6e1833ac9afa159.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/b117e66ce8a50901bb1cf97db6e1833ac9afa159.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/b117e66ce8a50901bb1cf97db6e1833ac9afa159.mp3'}],
#   'createdAt': '2023-04-20T16:27:56.461906Z',
#   'updatedAt': '2023-04-20T16:28:26.036320Z',
#   'lastPublishedAt': '2023-04-20T16:28:26.036320Z',
#   'tags': ['hardcore', 'electronic'],
#   'bookmarked': False},
#  {'id': '3175e',
#   'name': 'Xyris - Eviternity',
#   'description': "First released map in a bit.. \n\nthis song is much better than the remix in my opinion\n\nwill probably reup for lowers and stuff. I'll see\n\nFeedback: MrSquid#2854",
#   'uploader': {'id': 4301733,
#    'name': 'MrSquid',
#    'avatar': 'https://cdn.beatsaver.com/avatar/3cf41e077966e7b83fdea256a88f0592e977d6cd.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4301733/playlist'},
#   'metadata': {'bpm': 250.0,
#    'duration': 203,
#    'songName': 'Eviternity',
#    'songSubName': '',
#    'songAuthorName': 'Xyris',
#    'levelAuthorName': 'MrSquid'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 10,
#    'downvotes': 0,
#    'score': 0.8386},
#   'uploaded': '2023-04-20T16:08:53.346470Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '5f1800e733476bd5d4800d3eb55f54f78141c382',
#     'state': 'Published',
#     'createdAt': '2023-04-20T16:01:08.527844Z',
#     'sageScore': 3,
#     'diffs': [{'njs': 20.0,
#       'offset': -0.14,
#       'notes': 1642,
#       'bombs': 181,
#       'obstacles': 117,
#       'nps': 8.743,
#       'length': 782.542,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 6710,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 187.81,
#       'paritySummary': {'errors': 0, 'warns': 2, 'resets': 13},
#       'maxScore': 1503395}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/5f1800e733476bd5d4800d3eb55f54f78141c382.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/5f1800e733476bd5d4800d3eb55f54f78141c382.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/5f1800e733476bd5d4800d3eb55f54f78141c382.mp3'}],
#   'createdAt': '2023-04-11T22:44:39.248501Z',
#   'updatedAt': '2023-04-24T06:24:29.528048Z',
#   'lastPublishedAt': '2023-04-20T16:08:53.346470Z',
#   'tags': ['speed', 'tech', 'electronic'],
#   'bookmarked': False},
#  {'id': '31b4c',
#   'name': 'Lovejoy - Cause for concern',
#   'description': 'this song is underrated ngl\n\nlet me know where i can improve\n\nmy YT: https://www.youtube.com/channel/UC3blsOy0OlgoXDnpDatRpmg\n\npreview: https://youtu.be/IWN78ceLoV4\n\nupdate 29/4/23: added expert difficulty and increased njs on expert+ to 21. have fun!\n\nupdate 2/5/23: changed some of the patterns on expert+ to make it feel more like expert+ (if that makes sense). also actually made njs 21 and not 22. have fun!\n\nupdate 7/5/23: fixed the double direction in expert in the third chorus and also made the third chorus a bit more difficult. Have fun!\n\nupdate 12/5/23: Update 4, this is a big update. I added hard difficulty, lawless expert and expert plus and made normal expert plus more difficult (again)\n also i am releasing a new map soon so yay. have fun!',
#   'uploader': {'id': 134823,
#    'name': 'HeroicBanjo3809',
#    'avatar': 'https://cdn.beatsaver.com/avatar/f853dd6cecfd2a2b485f00155f7155f6f65a060d.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/134823/playlist'},
#   'metadata': {'bpm': 150.0,
#    'duration': 204,
#    'songName': 'Cause for Concern',
#    'songSubName': '',
#    'songAuthorName': 'Lovejoy',
#    'levelAuthorName': 'HeroicBanjo3809'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 2,
#    'downvotes': 6,
#    'score': 0.3406},
#   'uploaded': '2023-04-20T15:41:47.225204Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': 'e4fb971dc513906047580ef082b049cea69061ff',
#     'state': 'Published',
#     'createdAt': '2023-05-13T09:56:05.557001Z',
#     'sageScore': 1,
#     'diffs': [{'njs': 17.0,
#       'offset': 0.279,
#       'notes': 965,
#       'bombs': 2,
#       'obstacles': 17,
#       'nps': 4.871,
#       'length': 495.271,
#       'characteristic': 'Standard',
#       'difficulty': 'Hard',
#       'events': 4306,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 198.108,
#       'paritySummary': {'errors': 9, 'warns': 4, 'resets': 0},
#       'maxScore': 880555},
#      {'njs': 19.0,
#       'offset': -0.092,
#       'notes': 981,
#       'bombs': 0,
#       'obstacles': 16,
#       'nps': 4.952,
#       'length': 495.271,
#       'characteristic': 'Standard',
#       'difficulty': 'Expert',
#       'events': 4306,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 198.108,
#       'paritySummary': {'errors': 9, 'warns': 3, 'resets': 0},
#       'maxScore': 895275},
#      {'njs': 21.0,
#       'offset': -0.523,
#       'notes': 1034,
#       'bombs': 0,
#       'obstacles': 17,
#       'nps': 5.219,
#       'length': 495.271,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 4307,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 198.108,
#       'paritySummary': {'errors': 8, 'warns': 4, 'resets': 0},
#       'maxScore': 944035},
#      {'njs': 19.0,
#       'offset': -0.092,
#       'notes': 981,
#       'bombs': 0,
#       'obstacles': 15,
#       'nps': 4.952,
#       'length': 495.271,
#       'characteristic': 'Lawless',
#       'difficulty': 'Expert',
#       'events': 4306,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 198.108,
#       'paritySummary': {'errors': 9, 'warns': 3, 'resets': 0},
#       'maxScore': 895275},
#      {'njs': 21.0,
#       'offset': -0.523,
#       'notes': 1037,
#       'bombs': 0,
#       'obstacles': 17,
#       'nps': 5.235,
#       'length': 495.271,
#       'characteristic': 'Lawless',
#       'difficulty': 'ExpertPlus',
#       'events': 4307,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 198.108,
#       'paritySummary': {'errors': 8, 'warns': 5, 'resets': 0},
#       'maxScore': 946795}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/e4fb971dc513906047580ef082b049cea69061ff.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/e4fb971dc513906047580ef082b049cea69061ff.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/e4fb971dc513906047580ef082b049cea69061ff.mp3'}],
#   'createdAt': '2023-04-20T15:40:47.126920Z',
#   'updatedAt': '2023-05-18T17:14:00.962301Z',
#   'lastPublishedAt': '2023-05-13T09:56:12.093625Z',
#   'bookmarked': False},
#  {'id': '31b4b',
#   'name': '[Fitbeat] Momoland - Ready Or Not',
#   'description': 'Inspired by a great Audio Trip custom choreo from Chez, I thought this song would make for a fun fitbeat map in this game too.\n\nBig thanks to @Scarladore for taking a look at my map and giving detailed feedback, and also to @YobiTheCat for playtesting.\n\n~13 squats per minute; 43 squats total\n',
#   'uploader': {'id': 119875,
#    'name': 'meoaww',
#    'avatar': 'https://cdn.beatsaver.com/avatar/f91288eed1fb655478859699f3e2124bdf358651.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/119875/playlist'},
#   'metadata': {'bpm': 125.0,
#    'duration': 202,
#    'songName': 'Ready Or Not',
#    'songSubName': '[Fitbeat]',
#    'songAuthorName': 'Momoland',
#    'levelAuthorName': 'meoaww'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 128,
#    'downvotes': 3,
#    'score': 0.9433},
#   'uploaded': '2023-04-20T15:09:31.210280Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '44e4e288e3f941be50969050a88a6603ee1d42de',
#     'state': 'Published',
#     'createdAt': '2023-04-20T15:06:29.890984Z',
#     'sageScore': 4,
#     'diffs': [{'njs': 18.0,
#       'offset': -0.875,
#       'notes': 765,
#       'bombs': 45,
#       'obstacles': 135,
#       'nps': 3.945,
#       'length': 404.0,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 3992,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 193.92,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 15},
#       'maxScore': 696555,
#       'label': 'Ready Or Squat'}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/44e4e288e3f941be50969050a88a6603ee1d42de.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/44e4e288e3f941be50969050a88a6603ee1d42de.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/44e4e288e3f941be50969050a88a6603ee1d42de.mp3'}],
#   'curator': {'id': 11586,
#    'name': 'Kansas',
#    'hash': '5f813ecf6fd2400006d03fdd',
#    'avatar': 'https://cdn.beatsaver.com/avatar/01f95562c3153874aaa65422462281189fe4a59e.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'curatorTab': True,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/11586/playlist'},
#   'curatedAt': '2023-04-21T05:52:05.641144Z',
#   'createdAt': '2023-04-20T15:06:29.890984Z',
#   'updatedAt': '2023-06-15T10:14:54.885467Z',
#   'lastPublishedAt': '2023-04-20T15:09:31.210280Z',
#   'tags': ['fitness', 'k-pop', 'dance-style'],
#   'bookmarked': False},
#  {'id': '31b49',
#   'name': 'GOOD TIMES - Spasibo chto zhivoj',
#   'description': '',
#   'uploader': {'id': 129003,
#    'name': 'KellyKrolik',
#    'avatar': 'https://cdn.beatsaver.com/avatar/129003.jpg',
#    'type': 'SIMPLE',
#    'admin': False,
#    'curator': False,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/129003/playlist'},
#   'metadata': {'bpm': 136.0,
#    'duration': 214,
#    'songName': 'Spasibo chto zhivojj',
#    'songSubName': '',
#    'songAuthorName': 'GOOD TIMES',
#    'levelAuthorName': 'KellyKrolik'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 0,
#    'downvotes': 1,
#    'score': 0.3871},
#   'uploaded': '2023-04-20T14:06:26.411764Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': 'fa0533987b014a7ee1ca5740c12b520a67a81ade',
#     'state': 'Published',
#     'createdAt': '2023-04-20T14:06:04.357373Z',
#     'sageScore': 4,
#     'diffs': [{'njs': 13.0,
#       'offset': 0.0,
#       'notes': 785,
#       'bombs': 32,
#       'obstacles': 0,
#       'nps': 3.742,
#       'length': 475.5,
#       'characteristic': 'Standard',
#       'difficulty': 'Hard',
#       'events': 128,
#       'chroma': True,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 209.779,
#       'paritySummary': {'errors': 57, 'warns': 19, 'resets': 2},
#       'maxScore': 714955}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/fa0533987b014a7ee1ca5740c12b520a67a81ade.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/fa0533987b014a7ee1ca5740c12b520a67a81ade.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/fa0533987b014a7ee1ca5740c12b520a67a81ade.mp3'}],
#   'createdAt': '2023-04-20T14:06:04.357373Z',
#   'updatedAt': '2023-04-20T14:06:26.411764Z',
#   'lastPublishedAt': '2023-04-20T14:06:26.411764Z',
#   'tags': ['rock'],
#   'bookmarked': False},
#  {'id': '31b48',
#   'name': '[Arcs] Idol (Tv Size) [Oshi No Ko Opening] - Yoasobi',
#   'description': 'Showcase video\nhttps://youtu.be/QDauu9znnG0\n===========================\n*This map uses arcs which is only compatible with version 1.20 or newer*\n===========================\nLiterally made this map in a day with some autolights like how I usally do it with all my other anime opening maps. Also Im gonna be making difficuly in a 4 mapper collab of an AJR song. My next map will probably be another anime op.',
#   'uploader': {'id': 4335970,
#    'name': 'Scorefam',
#    'avatar': 'https://cdn.beatsaver.com/avatar/ffb0633b830f43850e7ee5ff02fd8f90926fb791.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4335970/playlist'},
#   'metadata': {'bpm': 166.0,
#    'duration': 94,
#    'songName': 'Idol (Tv Size) [Oshi No Ko Opening]',
#    'songSubName': '',
#    'songAuthorName': 'Yoasobi',
#    'levelAuthorName': 'Scorefam'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 311,
#    'downvotes': 11,
#    'score': 0.947,
#    'reviews': 1},
#   'uploaded': '2023-04-20T14:05:59.920939Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '1f7bb8342cb735d975d51cb0fa09306a0cab9394',
#     'state': 'Published',
#     'createdAt': '2023-04-20T14:03:17.253463Z',
#     'sageScore': 2,
#     'diffs': [{'njs': 18.0,
#       'offset': -0.34,
#       'notes': 437,
#       'bombs': 0,
#       'obstacles': 26,
#       'nps': 4.925,
#       'length': 245.5,
#       'characteristic': 'Standard',
#       'difficulty': 'Expert',
#       'events': 1458,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 88.735,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 394795}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/1f7bb8342cb735d975d51cb0fa09306a0cab9394.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/1f7bb8342cb735d975d51cb0fa09306a0cab9394.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/1f7bb8342cb735d975d51cb0fa09306a0cab9394.mp3'}],
#   'curator': {'id': 72422,
#    'name': 'tinkervr85',
#    'hash': '606294f0686b9f0006a2c475',
#    'avatar': 'https://cdn.beatsaver.com/avatar/67591b4b4654c981e1fd834c78dc4e50114a27b4.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': True,
#    'curatorTab': True,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/72422/playlist'},
#   'curatedAt': '2023-04-23T03:48:58.465114Z',
#   'createdAt': '2023-04-20T14:03:17.253463Z',
#   'updatedAt': '2023-04-23T03:48:58.465114Z',
#   'lastPublishedAt': '2023-04-20T14:05:59.920939Z',
#   'tags': ['balanced', 'anime'],
#   'bookmarked': False},
#  {'id': '31b47',
#   'name': 'Yooh - Good bye, Merry-Go-Round.',
#   'description': "heavily inspired by kizuflux's nulctrl",
#   'uploader': {'id': 4284943,
#    'name': 'abcbadq',
#    'hash': '5e0344ebe85d6800061edc97',
#    'avatar': 'https://cdn.beatsaver.com/avatar/44aa74df0986c29c29fb9cbae9541c8b74e19424.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4284943/playlist'},
#   'metadata': {'bpm': 185.0,
#    'duration': 127,
#    'songName': 'Good bye, Merry-Go-Round.',
#    'songSubName': '',
#    'songAuthorName': 'Yooh',
#    'levelAuthorName': 'abcbadq'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 30,
#    'downvotes': 3,
#    'score': 0.8419},
#   'uploaded': '2023-04-20T13:50:57.791534Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '4786a2117612498cd1d0b15e5d58024552683899',
#     'state': 'Published',
#     'createdAt': '2023-04-20T13:49:57.528268Z',
#     'sageScore': 5,
#     'diffs': [{'njs': 18.0,
#       'offset': -0.35,
#       'notes': 1239,
#       'bombs': 6,
#       'obstacles': 458,
#       'nps': 10.269,
#       'length': 372.0,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 5451,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 120.649,
#       'paritySummary': {'errors': 0, 'warns': 22, 'resets': 0},
#       'maxScore': 1132635,
#       'label': 'HahaWall'}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/4786a2117612498cd1d0b15e5d58024552683899.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/4786a2117612498cd1d0b15e5d58024552683899.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/4786a2117612498cd1d0b15e5d58024552683899.mp3'}],
#   'createdAt': '2023-04-20T13:45:52.020533Z',
#   'updatedAt': '2023-06-06T14:15:54.588154Z',
#   'lastPublishedAt': '2023-06-06T14:15:54.588154Z',
#   'bookmarked': False},
#  {'id': '31b45',
#   'name': 'Xyris - Dystopian Exodus of the Magical Girls',
#   'description': '1/3\nliterally has the venomous firefly voice sample',
#   'uploader': {'id': 4284943,
#    'name': 'abcbadq',
#    'hash': '5e0344ebe85d6800061edc97',
#    'avatar': 'https://cdn.beatsaver.com/avatar/44aa74df0986c29c29fb9cbae9541c8b74e19424.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4284943/playlist'},
#   'metadata': {'bpm': 260.0,
#    'duration': 139,
#    'songName': 'Dystopian Exodus of the Magical Girls',
#    'songSubName': '',
#    'songAuthorName': 'Xyris',
#    'levelAuthorName': 'abcbadq'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 59,
#    'downvotes': 6,
#    'score': 0.8632,
#    'reviews': 1},
#   'uploaded': '2023-04-20T13:50:47.602468Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': 'dfe011d8fb614ab4233e75310474097df3fa2bb6',
#     'state': 'Published',
#     'createdAt': '2023-07-12T03:20:46.534404Z',
#     'sageScore': 5,
#     'diffs': [{'njs': 18.0,
#       'offset': -1.3,
#       'notes': 592,
#       'bombs': 19,
#       'obstacles': 401,
#       'nps': 4.454,
#       'length': 576.0,
#       'characteristic': 'Standard',
#       'difficulty': 'Hard',
#       'events': 6393,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 132.923,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 537395,
#       'label': 'Quarterly'},
#      {'njs': 19.0,
#       'offset': -1.7,
#       'notes': 1014,
#       'bombs': 19,
#       'obstacles': 325,
#       'nps': 7.576,
#       'length': 580.0,
#       'characteristic': 'Standard',
#       'difficulty': 'Expert',
#       'events': 6393,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 133.846,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 925635,
#       'label': 'Yearly'},
#      {'njs': 21.0,
#       'offset': -0.039,
#       'notes': 1521,
#       'bombs': 19,
#       'obstacles': 318,
#       'nps': 11.364,
#       'length': 580.0,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 6393,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 133.846,
#       'paritySummary': {'errors': 0, 'warns': 33, 'resets': 0},
#       'maxScore': 1392075,
#       'label': 'Centennial Festival'}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/dfe011d8fb614ab4233e75310474097df3fa2bb6.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/dfe011d8fb614ab4233e75310474097df3fa2bb6.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/dfe011d8fb614ab4233e75310474097df3fa2bb6.mp3'}],
#   'createdAt': '2023-04-20T13:39:44.114689Z',
#   'updatedAt': '2023-07-12T03:21:11.206901Z',
#   'lastPublishedAt': '2023-07-12T03:21:11.206901Z',
#   'bookmarked': False},
#  {'id': '31b44',
#   'name': 'MESHUGGAH - The Abysmal Eye',
#   'description': 'Hey folks 😉\r\nNew Meshuggah map, took me way too long to finish, Mass Effect trilogy to blame here. Ex+ will be for bomb resets enthusiasts ^^\r\nUsed custom colors to be a bit loyal to their live performance.\r\nHope you enjoy, let me know your feedback  on Discord.\r\n\r\nMy thanks to monstor for the testplays\r\n\r\nDiscord : Sk4venger#6604\r\n\r\nLightshow : https://youtu.be/nYtQOAw9yaY\r\n\r\nGameplay : https://youtu.be/Ml3V2nY9LeI',
#   'uploader': {'id': 4285259,
#    'name': 'sk4venger',
#    'hash': '5f0b47eb8f03870006b0b424',
#    'avatar': 'https://cdn.beatsaver.com/avatar/960f5e14c61ec24a8879ca73672869d7002a1232.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4285259/playlist'},
#   'metadata': {'bpm': 175.0,
#    'duration': 298,
#    'songName': 'The Abysmal Eye',
#    'songSubName': '',
#    'songAuthorName': 'Meshuggah',
#    'levelAuthorName': 'Sk4venger'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 28,
#    'downvotes': 1,
#    'score': 0.8829},
#   'uploaded': '2023-04-20T13:38:13.310061Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '50903c9fec5d81101debec710fb6666e083c61fd',
#     'state': 'Published',
#     'createdAt': '2023-04-20T13:36:52.099862Z',
#     'sageScore': 5,
#     'diffs': [{'njs': 12.0,
#       'offset': -1.0,
#       'notes': 536,
#       'bombs': 0,
#       'obstacles': 112,
#       'nps': 1.832,
#       'length': 853.5,
#       'characteristic': 'Standard',
#       'difficulty': 'Easy',
#       'events': 1011,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 292.629,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 485875},
#      {'njs': 14.0,
#       'offset': 0.4,
#       'notes': 684,
#       'bombs': 2,
#       'obstacles': 112,
#       'nps': 2.337,
#       'length': 853.5,
#       'characteristic': 'Standard',
#       'difficulty': 'Normal',
#       'events': 1011,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 292.629,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 622035},
#      {'njs': 16.0,
#       'offset': 0.1,
#       'notes': 1134,
#       'bombs': 2,
#       'obstacles': 112,
#       'nps': 3.875,
#       'length': 853.5,
#       'characteristic': 'Standard',
#       'difficulty': 'Hard',
#       'events': 1011,
#       'chroma': False,
#       'me': False,
# ...
#       'maxScore': 386515},
#      {'njs': 16.0,
#       'offset': -0.6,
#       'notes': 543,
#       'bombs': 6,
#       'obstacles': 216,
#       'nps': 3.77,
#       'length': 302.5,
#       'characteristic': 'Standard',
#       'difficulty': 'Expert',
#       'events': 2696,
#       'chroma': False,
#       'me': False,
#       'ne': True,
#       'cinema': False,
#       'seconds': 144.048,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 4},
#       'maxScore': 492315},
#      {'njs': 18.0,
#       'offset': -0.75,
#       'notes': 658,
#       'bombs': 47,
#       'obstacles': 205,
#       'nps': 4.568,
#       'length': 302.5,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 2696,
#       'chroma': False,
#       'me': False,
#       'ne': True,
#       'cinema': False,
#       'seconds': 144.048,
#       'paritySummary': {'errors': 4, 'warns': 0, 'resets': 11},
#       'maxScore': 598115}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/ad7a886711bcdbab809cf195cc828a15210a2096.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/ad7a886711bcdbab809cf195cc828a15210a2096.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/ad7a886711bcdbab809cf195cc828a15210a2096.mp3'}],
#   'curator': {'id': 4284798,
#    'name': 'Scarladore',
#    'hash': '60bf6856b85f2d00062fd145',
#    'avatar': 'https://cdn.beatsaver.com/avatar/e03d173f69d9ecd25313ad67b9625ab3b3222b15.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': True,
#    'curatorTab': True,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4284798/playlist'},
#   'curatedAt': '2023-04-19T22:54:07.573428Z',
#   'createdAt': '2023-04-17T17:18:41.449480Z',
#   'updatedAt': '2023-04-19T22:54:07.573428Z',
#   'lastPublishedAt': '2023-04-19T18:00:00.425801Z',
#   'tags': ['fitness', 'dance-style', 'dance', 'electronic'],
#   'bookmarked': False},
#  {'id': '31afc',
#   'name': 'DIA - Will You Go Out with Me',
#   'description': 'This map is a special request by Timo#2909 :D\n\nJoin Beat Saber KPOP Discord!\nhttps://discord.gg/c9uHGYP\n\nLike most/all of my kpop maps? Use this playlist! (always up to date)\nhttps://beatsaver.com/playlists/315\n\nThanks to @fatahkent for helping out on the choreo refs part\n\nFeedback is always appreciated\nDiscord: eurnkung#6176',
#   'uploader': {'id': 4285115,
#    'name': 'eurnkung',
#    'hash': '609a7955686b9f0006a47313',
#    'avatar': 'https://cdn.beatsaver.com/avatar/d91ebeaac5291083052d6a4592ae428374039f0a.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4285115/playlist'},
#   'metadata': {'bpm': 140.0,
#    'duration': 195,
#    'songName': 'Will You Go Out with Me',
#    'songSubName': '',
#    'songAuthorName': 'DIA',
#    'levelAuthorName': 'eurnkung'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 64,
#    'downvotes': 3,
#    'score': 0.9065},
#   'uploaded': '2023-04-19T16:20:07.283622Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '61c0b127f0de220b78dff2074d92cf46f8387620',
#     'state': 'Published',
#     'createdAt': '2023-04-19T16:17:05.208575Z',
#     'sageScore': 3,
#     'diffs': [{'njs': 17.0,
#       'offset': -0.64,
#       'notes': 1024,
#       'bombs': 0,
#       'obstacles': 157,
#       'nps': 5.493,
#       'length': 435.0,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 3030,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 186.429,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 935555}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/61c0b127f0de220b78dff2074d92cf46f8387620.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/61c0b127f0de220b78dff2074d92cf46f8387620.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/61c0b127f0de220b78dff2074d92cf46f8387620.mp3'}],
#   'curator': {'id': 72422,
#    'name': 'tinkervr85',
#    'hash': '606294f0686b9f0006a2c475',
#    'avatar': 'https://cdn.beatsaver.com/avatar/67591b4b4654c981e1fd834c78dc4e50114a27b4.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': True,
#    'curatorTab': True,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/72422/playlist'},
#   'curatedAt': '2023-04-23T03:51:10.289308Z',
#   'createdAt': '2023-04-19T16:17:05.208575Z',
#   'updatedAt': '2023-07-31T06:00:44.787393Z',
#   'lastPublishedAt': '2023-04-19T16:20:07.283622Z',
#   'tags': ['balanced', 'dance-style', 'k-pop'],
#   'bookmarked': False},
#  {'id': '31afb',
#   'name': 'Tanger - Firestarter VIP',
#   'description': 'Requested by Fishering#4086',
#   'uploader': {'id': 78832,
#    'name': 'Specture7',
#    'hash': '5f874a8df4de930006a667bf',
#    'avatar': 'https://cdn.beatsaver.com/avatar/b821a86f538b10edbcc7ec0f20564b53ce2ca070.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/78832/playlist'},
#   'metadata': {'bpm': 135.0,
#    'duration': 187,
#    'songName': 'Firestarter VIP',
#    'songSubName': '',
#    'songAuthorName': 'Tanger',
#    'levelAuthorName': 'Specture7'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 10,
#    'downvotes': 0,
#    'score': 0.8386},
#   'uploaded': '2023-04-19T16:11:00.003825Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': 'd44136f911f93da4b3614398c24aa9ae308778f3',
#     'state': 'Published',
#     'createdAt': '2023-04-19T16:09:22.465904Z',
#     'sageScore': 4,
#     'diffs': [{'njs': 20.0,
#       'offset': -0.808,
#       'notes': 1569,
#       'bombs': 43,
#       'obstacles': 277,
#       'nps': 8.653,
#       'length': 408.0,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 7844,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 181.333,
#       'paritySummary': {'errors': 3, 'warns': 2, 'resets': 4},
#       'maxScore': 1436235}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/d44136f911f93da4b3614398c24aa9ae308778f3.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/d44136f911f93da4b3614398c24aa9ae308778f3.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/d44136f911f93da4b3614398c24aa9ae308778f3.mp3'}],
#   'createdAt': '2023-04-19T16:09:22.465904Z',
#   'updatedAt': '2023-09-03T22:47:54.352308Z',
#   'lastPublishedAt': '2023-04-19T16:11:00.003825Z',
#   'tags': ['balanced', 'tech', 'dubstep'],
#   'bookmarked': False},
#  {'id': '31ad4',
#   'name': "[V3 REMAP] K'naan ft. Adam Levine - Bang Bang",
#   'description': 'Showcase video\nhttps://youtu.be/J2sOFi-nxCk\n===========================\n*This map uses the rock environment which is only compatible with version 1.27 or newer*\n===========================\nOne year ago today I uploaded my very first map and I decided to remap it to see how much Ive improved as a mapper. Also I really love how the lights turned out.\n===========================\nThanks to @lekrkoekj and @swukpuff for testplaying :)',
#   'uploader': {'id': 4335970,
#    'name': 'Scorefam',
#    'avatar': 'https://cdn.beatsaver.com/avatar/ffb0633b830f43850e7ee5ff02fd8f90926fb791.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4335970/playlist'},
#   'metadata': {'bpm': 180.0,
#    'duration': 188,
#    'songName': 'Bang Bang',
#    'songSubName': '(V3 Remap)',
#    'songAuthorName': "K'naan ft. Adam Levine",
#    'levelAuthorName': 'Scorefam'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 142,
#    'downvotes': 3,
#    'score': 0.9475},
#   'uploaded': '2023-04-19T15:28:00.426152Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '929ec9095680c6ed08ead1c902ec314fea7d1859',
#     'state': 'Published',
#     'createdAt': '2023-04-19T07:25:08.222354Z',
#     'sageScore': 3,
#     'diffs': [{'njs': 18.0,
#       'offset': -0.2,
#       'notes': 783,
#       'bombs': 0,
#       'obstacles': 45,
#       'nps': 4.474,
#       'length': 525.0,
#       'characteristic': 'Standard',
#       'difficulty': 'Expert',
#       'events': 12,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 175.0,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 713115}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/929ec9095680c6ed08ead1c902ec314fea7d1859.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/929ec9095680c6ed08ead1c902ec314fea7d1859.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/929ec9095680c6ed08ead1c902ec314fea7d1859.mp3'}],
#   'curator': {'id': 4284201,
#    'name': 'nitronik.exe',
#    'hash': '5cff0b7798cc5a672c855d84',
#    'avatar': 'https://cdn.beatsaver.com/avatar/ab054640a94777ed7e92d91a505a85f8c5047be5.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': True,
#    'curatorTab': True,
#    'verifiedMapper': True,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4284201/playlist'},
#   'curatedAt': '2023-04-19T19:12:03.266395Z',
#   'createdAt': '2023-04-19T07:25:08.222354Z',
#   'updatedAt': '2023-05-21T18:36:49.054609Z',
#   'lastPublishedAt': '2023-04-19T15:28:00.426152Z',
#   'tags': ['balanced', 'pop'],
#   'bookmarked': False},
#  {'id': '31af7',
#   'name': 'Ultimate 1 Hand Challenge',
#   'description': 'this is fairly difficult so good luck\r\n\r\n0:00- Jiyuu no Tsubasa (628 BPM)\r\n0:31- Image Material (520 BPM)\r\n1:43- Nobody (600 BPM)\r\n2:46- Illegal Trap (640 BPM)\r\n3:13- Long Time Friends (540 BPM)\r\n3:49- Storm (600 BPM) \r\n5:42- Icicle Stinger (570 BPM)\r\n6:20- Gec 2 U (680 BPM)\r\n6:52- Blood Shake (570 BPM)\r\n\r\n\r\n',
#   'uploader': {'id': 4327060,
#    'name': 'soap420',
#    'avatar': 'https://cdn.beatsaver.com/avatar/4327060.jpg',
#    'type': 'SIMPLE',
#    'admin': False,
#    'curator': False,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4327060/playlist'},
#   'metadata': {'bpm': 200.0,
#    'duration': 495,
#    'songName': 'Ultimate 1 Hand Challenge',
#    'songSubName': '',
#    'songAuthorName': 'Various Artists',
#    'levelAuthorName': 'soap'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 2,
#    'downvotes': 3,
#    'score': 0.4454,
#    'reviews': 1},
#   'uploaded': '2023-04-19T15:17:24.212756Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '04bb7192e1169205ba8a95ad9845d6b05ce5e031',
#     'state': 'Published',
#     'createdAt': '2023-04-28T02:54:42.286927Z',
#     'sageScore': 1,
#     'diffs': [{'njs': 21.0,
#       'offset': -0.25,
#       'notes': 6848,
#       'bombs': 12,
#       'obstacles': 0,
#       'nps': 14.535,
#       'length': 1570.479,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 0,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 471.144,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 2},
#       'maxScore': 6292915,
#       'label': 'goob luck ;)'}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/04bb7192e1169205ba8a95ad9845d6b05ce5e031.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/04bb7192e1169205ba8a95ad9845d6b05ce5e031.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/04bb7192e1169205ba8a95ad9845d6b05ce5e031.mp3'}],
#   'createdAt': '2023-04-19T15:08:49.140991Z',
#   'updatedAt': '2023-04-28T02:54:45.151895Z',
#   'lastPublishedAt': '2023-04-28T02:54:45.151895Z',
#   'bookmarked': False},
#  {'id': '31af6',
#   'name': 'BOLAGET - Ikväll igen',
#   'description': 'Swedish pop group "bolaget" recently made a new song, why not make a map out of it?\n\nOriginal video: https://www.youtube.com/watch?v=lLw6VpcUpVE',
#   'uploader': {'id': 4288795,
#    'name': 'bullyschool',
#    'avatar': 'https://cdn.beatsaver.com/avatar/ebcafe66e09106ef1e9073e30f609572e7140265.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4288795/playlist'},
#   'metadata': {'bpm': 165.0,
#    'duration': 138,
#    'songName': 'Ikvall igen',
#    'songSubName': '',
#    'songAuthorName': 'BOLAGET',
#    'levelAuthorName': 'bullyschool'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 3,
#    'downvotes': 1,
#    'score': 0.625},
#   'uploaded': '2023-04-19T15:00:29.074616Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': '697a8390c727d9aee6ce87f35bc287008c812240',
#     'state': 'Published',
#     'createdAt': '2023-04-19T14:59:37.781673Z',
#     'sageScore': 3,
#     'diffs': [{'njs': 19.0,
#       'offset': 0.0,
#       'notes': 319,
#       'bombs': 66,
#       'obstacles': 728,
#       'nps': 2.683,
#       'length': 327.0,
#       'characteristic': 'Standard',
#       'difficulty': 'Expert',
#       'events': 792,
#       'chroma': False,
#       'me': True,
#       'ne': False,
#       'cinema': False,
#       'seconds': 118.909,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#       'maxScore': 286235}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/697a8390c727d9aee6ce87f35bc287008c812240.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/697a8390c727d9aee6ce87f35bc287008c812240.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/697a8390c727d9aee6ce87f35bc287008c812240.mp3'}],
#   'createdAt': '2023-04-19T14:59:37.781673Z',
#   'updatedAt': '2023-04-19T15:00:29.074616Z',
#   'lastPublishedAt': '2023-04-19T15:00:29.074616Z',
#   'tags': ['pop'],
#   'bookmarked': False},
#  {'id': '31aef',
#   'name': 'Syounen jidai(coverd by After hours ft.Yuuka Nagase) /少年時代',
#   'description': 'AFTER HOURS - 少年時代 (井上陽水)\n(ft.長瀬有花)\n\nsource:\nhttps://www.youtube.com/watch?v=VwF0B8oMizU\n\n************************************************\n★PredictStarNumber★\u3000by rakkyo150 \n************************************************\n(20230910)\nStandard-Hard : 3.53\nStandard-ExpertPlus : 5.98',
#   'uploader': {'id': 4285050,
#    'name': 'esa_esa',
#    'hash': '5ea020557abb000006b2af84',
#    'avatar': 'https://cdn.beatsaver.com/avatar/7df4b4e94ca46832c8356778672a680748f2ac66.png',
#    'type': 'DISCORD',
#    'admin': False,
#    'curator': False,
#    'playlistUrl': 'https://api.beatsaver.com/users/id/4285050/playlist'},
#   'metadata': {'bpm': 195.0,
#    'duration': 183,
#    'songName': 'syounen jidai(coverd by After hours ft.Yuuka Nagase)',
#    'songSubName': '',
#    'songAuthorName': 'Yosui Inoue',
#    'levelAuthorName': 'esa_esa'},
#   'stats': {'plays': 0,
#    'downloads': 0,
#    'upvotes': 29,
#    'downvotes': 2,
#    'score': 0.8612},
#   'uploaded': '2023-04-19T13:56:51.553367Z',
#   'automapper': False,
#   'ranked': False,
#   'qualified': False,
#   'versions': [{'hash': 'd64a37ebc60ed04845481c078bbe509a4dc40e6b',
#     'state': 'Published',
#     'createdAt': '2023-04-19T13:51:18.566143Z',
#     'sageScore': 5,
#     'diffs': [{'njs': 15.0,
#       'offset': 0.6,
#       'notes': 395,
#       'bombs': 86,
#       'obstacles': 104,
#       'nps': 2.31,
#       'length': 555.782,
#       'characteristic': 'Standard',
#       'difficulty': 'Hard',
#       'events': 1328,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 171.01,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 15},
#       'maxScore': 356155},
#      {'njs': 18.0,
#       'offset': -0.2,
#       'notes': 832,
#       'bombs': 28,
#       'obstacles': 66,
#       'nps': 4.865,
#       'length': 555.812,
#       'characteristic': 'Standard',
#       'difficulty': 'ExpertPlus',
#       'events': 1319,
#       'chroma': False,
#       'me': False,
#       'ne': False,
#       'cinema': False,
#       'seconds': 171.019,
#       'paritySummary': {'errors': 0, 'warns': 0, 'resets': 3},
#       'maxScore': 758195}],
#     'downloadURL': 'https://r2cdn.beatsaver.com/d64a37ebc60ed04845481c078bbe509a4dc40e6b.zip',
#     'coverURL': 'https://na.cdn.beatsaver.com/d64a37ebc60ed04845481c078bbe509a4dc40e6b.jpg',
#     'previewURL': 'https://na.cdn.beatsaver.com/d64a37ebc60ed04845481c078bbe509a4dc40e6b.mp3'}],
#   'createdAt': '2023-04-19T13:51:18.566143Z',
#   'updatedAt': '2023-09-10T02:14:16.065745Z',
#   'lastPublishedAt': '2023-04-19T13:56:51.553367Z',
#   'bookmarked': False}]

# %%
response['docs'][0]
# Out:
# {'id': '36a0d',
#  'name': 'Bishu - Bomb (feat. LeyeT)',
#  'description': 'bomb',
#  'uploader': {'id': 4341006,
#   'name': 'spinposts',
#   'avatar': 'https://cdn.beatsaver.com/avatar/4341006.jpg',
#   'type': 'SIMPLE',
#   'admin': False,
#   'curator': False,
#   'playlistUrl': 'https://api.beatsaver.com/users/id/4341006/playlist'},
#  'metadata': {'bpm': 150.0,
#   'duration': 175,
#   'songName': 'Bomb (feat. LeyeT)',
#   'songSubName': '',
#   'songAuthorName': 'Bishu',
#   'levelAuthorName': 'spinout'},
#  'stats': {'plays': 0,
#   'downloads': 0,
#   'upvotes': 0,
#   'downvotes': 0,
#   'score': 0.5},
#  'uploaded': '2023-10-22T16:41:38.056531Z',
#  'automapper': False,
#  'ranked': False,
#  'qualified': False,
#  'versions': [{'hash': 'e66cd98f4ec419aab1eef53a01ee0fd73777ed88',
#    'state': 'Published',
#    'createdAt': '2023-10-22T16:41:33.632727Z',
#    'sageScore': 3,
#    'diffs': [{'njs': 18.0,
#      'offset': -0.5,
#      'notes': 716,
#      'bombs': 0,
#      'obstacles': 374,
#      'nps': 4.232,
#      'length': 423.0,
#      'characteristic': 'Standard',
#      'difficulty': 'ExpertPlus',
#      'events': 2502,
#      'chroma': False,
#      'me': False,
#      'ne': False,
#      'cinema': False,
#      'seconds': 169.2,
#      'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#      'maxScore': 651475,
#      'label': 'BOMB'}],
#    'downloadURL': 'https://r2cdn.beatsaver.com/e66cd98f4ec419aab1eef53a01ee0fd73777ed88.zip',
#    'coverURL': 'https://na.cdn.beatsaver.com/e66cd98f4ec419aab1eef53a01ee0fd73777ed88.jpg',
#    'previewURL': 'https://na.cdn.beatsaver.com/e66cd98f4ec419aab1eef53a01ee0fd73777ed88.mp3'}],
#  'createdAt': '2023-10-22T16:41:33.632727Z',
#  'updatedAt': '2023-10-22T16:41:38.056531Z',
#  'lastPublishedAt': '2023-10-22T16:41:38.056531Z',
#  'tags': ['balanced', 'electronic'],
#  'bookmarked': False}

# %%
response['docs'][0]['versions']
# Out:
# [{'hash': 'e66cd98f4ec419aab1eef53a01ee0fd73777ed88',
#   'state': 'Published',
#   'createdAt': '2023-10-22T16:41:33.632727Z',
#   'sageScore': 3,
#   'diffs': [{'njs': 18.0,
#     'offset': -0.5,
#     'notes': 716,
#     'bombs': 0,
#     'obstacles': 374,
#     'nps': 4.232,
#     'length': 423.0,
#     'characteristic': 'Standard',
#     'difficulty': 'ExpertPlus',
#     'events': 2502,
#     'chroma': False,
#     'me': False,
#     'ne': False,
#     'cinema': False,
#     'seconds': 169.2,
#     'paritySummary': {'errors': 0, 'warns': 0, 'resets': 0},
#     'maxScore': 651475,
#     'label': 'BOMB'}],
#   'downloadURL': 'https://r2cdn.beatsaver.com/e66cd98f4ec419aab1eef53a01ee0fd73777ed88.zip',
#   'coverURL': 'https://na.cdn.beatsaver.com/e66cd98f4ec419aab1eef53a01ee0fd73777ed88.jpg',
#   'previewURL': 'https://na.cdn.beatsaver.com/e66cd98f4ec419aab1eef53a01ee0fd73777ed88.mp3'}]

# %%
response['docs'][0]['tags']
# Out:
# ['balanced', 'electronic']

# %% [markdown]
# # functional stuff

# %%
bs_data = []

# %%
# makes a dictionary from the data of each song in response, then adds it to the BS data list.

for i in range(len(response['docs'])):
    song = {}
    song['bs_map_id'] = response['docs'][i]['id']
    song['title'] = response['docs'][i]['metadata']['songName']
    song['artist'] = response['docs'][i]['metadata']['songAuthorName']
    song['mapper_name'] = response['docs'][i]['uploader']['name']
    song['mapper_id'] = response['docs'][i]['uploader']['id']
    song['duration_seconds'] = response['docs'][i]['metadata']['duration']
    song['auto_mapped'] = response['docs'][i]['automapper']
    song['upload_date'] = response['docs'][i]['lastPublishedAt']
    try: 
        song['tags'] = response['docs'][i]['tags']
    except:
        song['tags'] = ['none']
    song['difficulties'] = [response['docs'][i]['versions'][0]['diffs'][x]['difficulty'] for x in range(len(response['docs'][i]['versions'][0]['diffs']))]
    bs_data.append(song)

# %%
bs_data
# Out:
# [{'bs_map_id': '36a0d',
#   'title': 'Bomb (feat. LeyeT)',
#   'artist': 'Bishu',
#   'mapper_name': 'spinposts',
#   'mapper_id': 4341006,
#   'duration_seconds': 175,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T16:41:38.056531Z',
#   'tags': ['balanced', 'electronic'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '36a0b',
#   'title': 'Well',
#   'artist': 'my friend',
#   'mapper_name': 'templewatcheye',
#   'mapper_id': 164529,
#   'duration_seconds': 33,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T16:32:38.630568Z',
#   'tags': ['challenge', 'speed', 'comedy-meme', 'classical-orchestral'],
#   'difficulties': ['Hard', 'Expert', 'ExpertPlus']},
#  {'bs_map_id': '36a01',
#   'title': "Can't let go",
#   'artist': 'DJVI',
#   'mapper_name': 'Skullsvr1123',
#   'mapper_id': 159767,
#   'duration_seconds': 85,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T16:17:52.362980Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369ff',
#   'title': 'Take a Hint x5',
#   'artist': 'ゴミ太郎',
#   'mapper_name': 'henrygames',
#   'mapper_id': 4232131,
#   'duration_seconds': 386,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T16:04:42.750047Z',
#   'tags': ['challenge', 'speed', 'hardcore'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369fe',
#   'title': 'Zombified',
#   'artist': 'Falling In Reverse',
#   'mapper_name': 'zraix',
#   'mapper_id': 22889,
#   'duration_seconds': 222,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T15:51:49.041848Z',
#   'tags': ['metal'],
#   'difficulties': ['Hard', 'Expert', 'ExpertPlus']},
#  {'bs_map_id': '369fd',
#   'title': 'IBUKI',
#   'artist': 'Analog digitaL',
#   'mapper_name': 'OTG',
#   'mapper_id': 4297784,
#   'duration_seconds': 142,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T15:49:31.044465Z',
#   'tags': ['video-game-soundtrack', 'dance'],
#   'difficulties': ['Expert']},
#  {'bs_map_id': '369fc',
#   'title': 'Why am I anxious',
#   'artist': 'Tom Cardy',
#   'mapper_name': 'zraix',
#   'mapper_id': 22889,
#   'duration_seconds': 108,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T15:47:06.439291Z',
#   'tags': ['comedy-meme'],
#   'difficulties': ['Expert']},
#  {'bs_map_id': '369fb',
#   'title': 'CHAOS',
#   'artist': 'Æsir',
#   'mapper_name': 'OTG',
#   'mapper_id': 4297784,
#   'duration_seconds': 218,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T15:44:01.853561Z',
#   'tags': ['video-game-soundtrack', 'dance'],
#   'difficulties': ['Expert']},
#  {'bs_map_id': '369fa',
#   'title': 'You',
#   'artist': 'Imil',
#   'mapper_name': 'Remec',
#   'mapper_id': 4285621,
#   'duration_seconds': 127,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T15:38:07.756990Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369f8',
#   'title': 'Body Talk',
#   'artist': 'M2U',
#   'mapper_name': 'OTG',
#   'mapper_id': 4297784,
#   'duration_seconds': 123,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T15:34:48.182941Z',
#   'tags': ['video-game-soundtrack', 'dance'],
#   'difficulties': ['Expert']},
#  {'bs_map_id': '369f7',
#   'title': 'Beautiful Lie',
#   'artist': 'MINEXO feat. IMANI',
#   'mapper_name': 'OTG',
#   'mapper_id': 4297784,
#   'duration_seconds': 156,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T15:32:16.332165Z',
#   'tags': ['video-game-soundtrack', 'dance'],
#   'difficulties': ['Expert']},
#  {'bs_map_id': '369f6',
#   'title': 'Drop',
#   'artist': '篤志',
#   'mapper_name': 'OTG',
#   'mapper_id': 4297784,
#   'duration_seconds': 137,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T15:52:42.184505Z',
#   'tags': ['video-game-soundtrack', 'dance'],
#   'difficulties': ['Expert']},
#  {'bs_map_id': '369f5',
#   'title': 'big pp randy',
#   'artist': 'gigglesaurus',
#   'mapper_name': 'templewatcheye',
#   'mapper_id': 164529,
#   'duration_seconds': 24,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T15:18:36.095660Z',
#   'tags': ['challenge', 'speed', 'comedy-meme', 'kids-family'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369f0',
#   'title': 'MOAI MONEY',
#   'artist': 'Exyl',
#   'mapper_name': 'bsNico__',
#   'mapper_id': 113317,
#   'duration_seconds': 158,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T15:03:41.411298Z',
#   'tags': ['tech', 'speed', 'electronic', 'techno'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369ee',
#   'title': 'Hyper banquet',
#   'artist': 'paradot',
#   'mapper_name': 'NanaCat',
#   'mapper_id': 4285000,
#   'duration_seconds': 315,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T14:45:00.875019Z',
#   'tags': ['balanced', 'hardcore', 'electronic', 'challenge'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369ed',
#   'title': 'Abstruse Dilemma',
#   'artist': 'Ashrtount vs. D-D-Dice',
#   'mapper_name': 'Sobas',
#   'mapper_id': 4286549,
#   'duration_seconds': 162,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T14:37:37.283583Z',
#   'tags': ['balanced', 'speed', 'video-game-soundtrack'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369ec',
#   'title': 'God Is Dead',
#   'artist': 'The Dali Thundering Concept',
#   'mapper_name': 'sk4venger',
#   'mapper_id': 4285259,
#   'duration_seconds': 158,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T14:34:19.921677Z',
#   'tags': ['balanced', 'metal'],
#   'difficulties': ['Easy', 'Normal', 'Hard', 'Expert', 'ExpertPlus']},
#  {'bs_map_id': '369eb',
#   'title': 'Myron',
#   'artist': 'Lil Uzi Vert',
#   'mapper_name': 'gagecorduck',
#   'mapper_id': 4286472,
#   'duration_seconds': 228,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T16:44:20.935499Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369e6',
#   'title': '(New Version)Endless Tears -11eyes CrossOver OP-',
#   'artist': 'Tatsh(feat.AYANE)',
#   'mapper_name': 'kagepoyo',
#   'mapper_id': 4354981,
#   'duration_seconds': 121,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T13:37:28.148856Z',
#   'tags': ['none'],
#   'difficulties': ['Expert', 'ExpertPlus']},
#  {'bs_map_id': '369e5',
#   'title': 'Kioku no Kakera',
#   'artist': 'feat.Sana',
#   'mapper_name': 'kagepoyo',
#   'mapper_id': 4354981,
#   'duration_seconds': 113,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T13:18:47.936532Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369d8',
#   'title': 'Egao Ni Aitai',
#   'artist': 'Rie Hamada',
#   'mapper_name': 'muu3',
#   'mapper_id': 4338378,
#   'duration_seconds': 95,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T13:07:28.251215Z',
#   'tags': ['anime'],
#   'difficulties': ['Hard']},
#  {'bs_map_id': '3699a',
#   'title': 'Real world',
#   'artist': 'Loossemble',
#   'mapper_name': 'Jonas_0_0',
#   'mapper_id': 120215,
#   'duration_seconds': 192,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T12:25:44.928125Z',
#   'tags': ['k-pop', 'balanced'],
#   'difficulties': ['Easy', 'Normal', 'Hard', 'Expert', 'ExpertPlus']},
#  {'bs_map_id': '369d0',
#   'title': 'Gladiator',
#   'artist': 'Jann',
#   'mapper_name': 'foxtasty6',
#   'mapper_id': 163586,
#   'duration_seconds': 218,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T12:14:56.467750Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369cb',
#   'title': 'mjk',
#   'artist': '7_7',
#   'mapper_name': 'rise',
#   'mapper_id': 852,
#   'duration_seconds': 163,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T11:07:09.888967Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369c5',
#   'title': 'Diamond Eyes',
#   'artist': 'SYNTHETIC',
#   'mapper_name': 'wangyufy',
#   'mapper_id': 4285274,
#   'duration_seconds': 218,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T06:56:28.886649Z',
#   'tags': ['challenge'],
#   'difficulties': ['Expert', 'ExpertPlus']},
#  {'bs_map_id': '369b9',
#   'title': 'Wagamama Party Night',
#   'artist': 'Tokimeki Idol Project',
#   'mapper_name': 'akikucorn',
#   'mapper_id': 152605,
#   'duration_seconds': 224,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T06:19:53.541678Z',
#   'tags': ['balanced', 'j-pop'],
#   'difficulties': ['Easy',
#    'Normal',
#    'Hard',
#    'Expert',
#    'ExpertPlus',
#    'ExpertPlus']},
#  {'bs_map_id': '369b5',
#   'title': '芭啦芭啦樱之花',
#   'artist': '郭富城',
#   'mapper_name': 'ken-UMA',
#   'mapper_id': 164213,
#   'duration_seconds': 229,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T05:20:29.566263Z',
#   'tags': ['accuracy', 'pop', 'dance'],
#   'difficulties': ['Expert']},
#  {'bs_map_id': '369b4',
#   'title': 'Районы-кварталы',
#   'artist': 'Звери ',
#   'mapper_name': 'Felarice',
#   'mapper_id': 165824,
#   'duration_seconds': 207,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T05:01:05.469855Z',
#   'tags': ['accuracy', 'rock'],
#   'difficulties': ['Hard']},
#  {'bs_map_id': '369b3',
#   'title': 'Fire Inside',
#   'artist': 'Gemini',
#   'mapper_name': 'deltafox',
#   'mapper_id': 3999,
#   'duration_seconds': 217,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T04:25:06.854626Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369b2',
#   'title': 'Booty V10',
#   'artist': 'Skullsvr1123',
#   'mapper_name': 'Skullsvr1123',
#   'mapper_id': 159767,
#   'duration_seconds': 23,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T04:24:49.320791Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369b1',
#   'title': 'Booty V9',
#   'artist': 'Skullsvr1123',
#   'mapper_name': 'Skullsvr1123',
#   'mapper_id': 159767,
#   'duration_seconds': 23,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T04:21:42.650149Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369af',
#   'title': 'Main Theme Orchestra',
#   'artist': 'Gooseworx',
#   'mapper_name': 'Elevator',
#   'mapper_id': 4284739,
#   'duration_seconds': 63,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T04:17:22.636581Z',
#   'tags': ['balanced', 'tv-movie-soundtrack', 'instrumental'],
#   'difficulties': ['Expert', 'ExpertPlus']},
#  {'bs_map_id': '369aa',
#   'title': 'Paraselene',
#   'artist': 'Kobaryo, Nyankovsky',
#   'mapper_name': 'Timmyboi101',
#   'mapper_id': 900,
#   'duration_seconds': 421,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T03:58:56.692451Z',
#   'tags': ['none'],
#   'difficulties': ['Expert', 'ExpertPlus']},
#  {'bs_map_id': '369ab',
#   'title': 'HE JUMPED?!?!',
#   'artist': 'NutshellAnimations',
#   'mapper_name': 'WooitCheese',
#   'mapper_id': 168429,
#   'duration_seconds': 15,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T03:48:51.992809Z',
#   'tags': ['dance-style', 'comedy-meme', 'pop'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369a8',
#   'title': 'towering_cock',
#   'artist': '71bigdaddy',
#   'mapper_name': 'dont_care',
#   'mapper_id': 162022,
#   'duration_seconds': 51,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T03:28:26.410479Z',
#   'tags': ['none'],
#   'difficulties': ['Normal', 'Hard', 'Expert', 'ExpertPlus']},
#  {'bs_map_id': '369a7',
#   'title': 'lμv-zukkyun',
#   'artist': 'yบ2บ',
#   'mapper_name': 'Sky-BTW',
#   'mapper_id': 4286795,
#   'duration_seconds': 122,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T03:12:34.658390Z',
#   'tags': ['challenge'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369a6',
#   'title': 'Whitehouse',
#   'artist': 'HGich.T',
#   'mapper_name': 'KMA',
#   'mapper_id': 4309251,
#   'duration_seconds': 115,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T02:50:00.381374Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369a5',
#   'title': '͏',
#   'artist': 'katagiri',
#   'mapper_name': 'Switronic',
#   'mapper_id': 4286837,
#   'duration_seconds': 120,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T02:48:52.180342Z',
#   'tags': ['challenge', 'tech'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369a3',
#   'title': 'Lucid traveler',
#   'artist': 'Akira Complex VS 3R2',
#   'mapper_name': 'Mystrik',
#   'mapper_id': 4284922,
#   'duration_seconds': 160,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T02:41:09.186859Z',
#   'tags': ['challenge', 'tech', 'electronic', 'dance'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369a4',
#   'title': 'Idolize',
#   'artist': 'Creo',
#   'mapper_name': 'CosmonautSaitni',
#   'mapper_id': 4326833,
#   'duration_seconds': 165,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T02:40:59.428980Z',
#   'tags': ['challenge'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369a2',
#   'title': 'Hi Hi',
#   'artist': 'DJ Witch Girl',
#   'mapper_name': 'VoltageChallengePosts',
#   'mapper_id': 4349351,
#   'duration_seconds': 158,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T13:35:32.232836Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369a1',
#   'title': 're: re: re: i made a snail pancake',
#   'artist': 'jorj1357',
#   'mapper_name': 'Mystrik',
#   'mapper_id': 4284922,
#   'duration_seconds': 107,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T02:39:13.797677Z',
#   'tags': ['challenge', 'dance-style', 'soul', 'electronic'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '369a0',
#   'title': 'Beyond the Geostationary Orbit Level',
#   'artist': 'Camellia',
#   'mapper_name': 'edgiiiiiiiii',
#   'mapper_id': 4327102,
#   'duration_seconds': 299,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T16:22:12.077753Z',
#   'tags': ['none'],
#   'difficulties': ['Expert', 'ExpertPlus']},
#  {'bs_map_id': '3699f',
#   'title': 'GET OUT WHILE YOU STILL CAAAAAAAAAAAAAAAAAAAAAAAAAN V2',
#   'artist': 'Baldi',
#   'mapper_name': 'Skullsvr1123',
#   'mapper_id': 159767,
#   'duration_seconds': 16,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T01:50:44.130653Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '3699e',
#   'title': "It's Time To Griddy!",
#   'artist': 'Griddy Kid',
#   'mapper_name': 'epicgamer9009',
#   'mapper_id': 168587,
#   'duration_seconds': 12,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T00:26:08.954225Z',
#   'tags': ['dance', 'comedy-meme', 'tech', 'speed'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '3699d',
#   'title': ' oh oh oh we re in heaven',
#   'artist': 'oh oh oh we re in heaven guy',
#   'mapper_name': 'dont_care',
#   'mapper_id': 162022,
#   'duration_seconds': 24,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T00:20:55.056781Z',
#   'tags': ['none'],
#   'difficulties': ['ExpertPlus', 'ExpertPlus']},
#  {'bs_map_id': '3699c',
#   'title': 'skibidi V2',
#   'artist': 'skibidi GUY',
#   'mapper_name': 'dont_care',
#   'mapper_id': 162022,
#   'duration_seconds': 15,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T00:19:23.579193Z',
#   'tags': ['none'],
#   'difficulties': ['Expert', 'ExpertPlus']},
#  {'bs_map_id': '3699b',
#   'title': "i'm home alone [;   (meme)",
#   'artist': 'NutshellAnimations',
#   'mapper_name': 'WooitCheese',
#   'mapper_id': 168429,
#   'duration_seconds': 21,
#   'auto_mapped': False,
#   'upload_date': '2023-10-22T00:18:07.672660Z',
#   'tags': ['drum-and-bass', 'pop', 'balanced'],
#   'difficulties': ['ExpertPlus']},
#  {'bs_map_id': '36999',
#   'title': 'Mr. Incorrect',
#   'artist': 'Malcolm Todd',
#   'mapper_name': 'sugarwoofer',
#   'mapper_id': 157131,
#   'duration_seconds': 173,
#   'auto_mapped': False,
#   'upload_date': '2023-10-21T22:02:05.054077Z',
#   'tags': ['none'],
#   'difficulties': ['Expert']},
#  {'bs_map_id': '36998',
#   'title': 'Photocathode',
#   'artist': 'staswalle',
#   'mapper_name': 'minerdiscovery',
#   'mapper_id': 164421,
#   'duration_seconds': 176,
#   'auto_mapped': False,
#   'upload_date': '2023-10-21T21:57:51.829005Z',
#   'tags': ['none'],
#   'difficulties': ['Easy']}]

# %%
#turn the list into a dataframe

df = pd.DataFrame(bs_data)
df.shape
# Out:
# (50, 10)

# %%
# Normal Export, will overwrite existing data every time:
df.to_csv('beatsaver_songs.csv') 

# append export:
# df.to_csv('beatsaver_songs.csv', mode='a', headers=False)
